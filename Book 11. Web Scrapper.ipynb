# %% [markdown]
# <h1>Book 11. Web Scrapper</h1><hr>

# %% [markdown]
# Web scrapper is a program that can scrap data from a website. By scaning the HTML elements in the website.
#
# We will be using <b>BeautifulSoup</b> and <b>requests</b> package to do it.

# %%
from bs4 import BeautifulSoup

import requests

# %% [markdown]
# Now lets pass a request to a website to get data from it.

# %%
r  = requests.get("http://boingboing.net")
print(r)
# Out:
# <Response [200]>

# %% [markdown]
# Response code <b>200</b> indicates the connection was successful
#
# <b>Connection Status</b><br>
# <ul>
#     <li><u>1xx (information)</u>: The server received the request but some extra information for the clinet.
#     </li>
#       <li><u>2xx (success)</u>: It worked: every success code other than 200 conveys extra details.
#     </li>
#       <li><u>3xx (redirection)</u>: The resource moved, so the response returns the new URL to the client.
#     </li>
#       <li><u>4xx (client error)</u>: Some problem from the client side, such as famous 404(not found). 418 (I'm a teapot) was an April Fool's joke.
#     </li>
#       <li><u>5xx (server error)</u>: 500 is the generic whoops; you might see a 502(bad gateway) if there's some disconnect between a web server and a backend application server.
#     </li>
# </ul>

# %%
data = r.text
print(data)
# r.text gives us the text content got by the request
# below what you can see is the text content of the request
# content of request is always got as HTML format. This is the same format which rendered on your browser. And browser renders HTML to a webpage UI.
# Out:
# <!doctype html>
# <html lang="en-US">
#
# <head>
#
# <title>Boing Boing - A Directory of Mostly Wonderful Things</title>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width">
#
# <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.5.18/webfont.js"></script>
# <script>
#   WebFont.load({
#     google: {
#       families: ['Raleway:600,800,400','Libre+Baskerville:400,700,400italic']
#     }
#   });
# </script>
#
# 	<link rel="stylesheet" href="https://media.boingboing.net/wp-content/themes/bng/style.css?=v1" type="text/css" media="all" />
#
# 	<!-- Jetpack Site Verification Tags -->
# <meta name="google-site-verification" content="2Z2CdDZoCt3kedjrHnPrbA3HjYnoXwwgy2pjFo552ws" />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Boing Boing &raquo; Feed" href="https://boingboing.net/feed" />
# <link rel="alternate" type="application/rss+xml" title="Boing Boing &raquo; Comments Feed" href="https://boingboing.net/comments/feed" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/boingboing.net\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='jetpack_css-css'  href='https://media.boingboing.net/wp-content/plugins/jetpack/css/jetpack.css?ver=6.5' type='text/css' media='all' />
# <link rel='https://api.w.org/' href='https://boingboing.net/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://boingboing.net/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://media.boingboing.net/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 4.9.8" />
# <link rel="canonical" href="https://boingboing.net/" />
# <link rel='shortlink' href='https://boingboing.net/' />
# <link rel="alternate" type="application/json+oembed" href="https://boingboing.net/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fboingboing.net%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://boingboing.net/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fboingboing.net%2F&#038;format=xml" />
#
# <link rel='dns-prefetch' href='//i0.wp.com'/>
# <link rel='dns-prefetch' href='//i1.wp.com'/>
# <link rel='dns-prefetch' href='//i2.wp.com'/>
# <style type='text/css'>img#wpstats{display:none}</style><meta name="description" content="Brain candy for Happy Mutants" />
#
# <!-- Jetpack Open Graph Tags -->
# <meta property="og:type" content="website" />
# <meta property="og:title" content="Boing Boing" />
# <meta property="og:description" content="Brain candy for Happy Mutants" />
# <meta property="og:url" content="https://boingboing.net/" />
# <meta property="og:site_name" content="Boing Boing" />
# <meta property="og:locale" content="en_US" />
# <meta name="twitter:text:title" content="Homepage" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:site" content="@boingboing" />
# <meta property="og:image" content="https://media.boingboing.net/wp-content/themes/bng/i/placeholder.png" />
# <meta property="og:image:width" content="1600" />
# <meta property="og:image:height" content="900" />
# <meta name="twitter:image" content="https://media.boingboing.net/wp-content/themes/bng/i/placeholder.png" />
#
# <!-- End Jetpack Open Graph Tags -->
# <link rel="icon" href="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=32%2C32&#038;ssl=1" sizes="32x32" />
# <link rel="icon" href="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=158%2C158&#038;ssl=1" sizes="192x192" />
# <link rel="apple-touch-icon-precomposed" href="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=158%2C158&#038;ssl=1" />
# <meta name="msapplication-TileImage" content="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=158%2C158&#038;ssl=1" />
# <script>
#   (function (s,o,n,a,r,i,z,e) {s['StackSonarObject']=r;s[r]=s[r]||function(){
#   (s[r].q=s[r].q||[]).push(arguments)},s[r].l=1*new Date();i=o.createElement(n),
#   z=o.getElementsByTagName(n)[0];i.async=1;i.src=a;z.parentNode.insertBefore(i,z)
#   })(window,document,'script','https://www.stack-sonar.com/ping.js','stackSonar');
#
#   stackSonar('stack-connect-wp', "6Mp0z_hYN4uKoN7SaPiUOQ");
# </script>
#
# 	<!-- AD CODE -->
#
# <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
# <script>
#
#   var pageType = 'Homepage'; // Targeting to 'Feature' or 'Homepage' or 'Blog'
#
#   // Barkeep
#   (function() {
#     var url = '//burnside.dtcn.com/barkeep/barkeep.min.js';
#     var args = {
#       //main container of all bars
#       //if no container is found, one is made with the given selector
#       //all pints are collected and maintained within this one container
#       container_sel:   'h-bartender',
#       //target bars by this class
#       pint_bar_class:  'h-pint',
#       //first wrapper element class name, used for positioning
#       pint_pos_class:  'm-pint-pos',
#       //second wrapper element class name (this will be the outermost container of each bar)
#       pint_wrap_class: 'm-pint-wrap',
#       //class that's appeneded to the pint when in a fixed position
#       fixed_class:     'is-fixed',
#       //class to append when pint is no longer active
#       inactive_class:  'is-dead',
#       //default bar type (static | fixed)
#       bar_type:        'static' ,
#       //class to attach close event listener to
#       do_remove_sel:   'h-do-remove-pint',
#       //enable drop shadows on pints
#       drop_shadows:    false,
#       //fires on initialization of obj
#       //passed param is reference to the object itself
#       init: self => {},
#       //fires when pint moves from fixed to static positioning
#       //passed param is the bar element
#       on_bar_down: _bar => {}
#     };
#
#     var _script = document.createElement('script');
#     _script.onload = function() {
#       window.Barkeep = new _Barkeep(args);
#       console.log('Barkeep Loaded');
#
#       var url = '//burnside.dtcn.com/burnside.min.js';
#       var _head = document.head || document.getElementsByTagName('head')[0];
#       var demo_key = 'dtdemo';
#       regex = new RegExp('[\\?&]' + demo_key + '=([a-zA-Z0-9_-]{1,50})');
#       results = regex.exec(window.location.search);
#       var demo = (results) ? decodeURIComponent(results[1]) : '';
#
#       // Burnside
#       var _args = {
#         debug:     false,     // show logs in console
#         demo_key:  demo_key,  // demo targeting key
#         demo_val:  demo,      // demo targeting val, if adblocked, demo_val='adblock'
#         prefix:    'dtads',   // prefix for slots
#         krux_id:   'q7qawfhbx',
#
#         experiences:  {
#           'desktop': 968,
#           'tablet':  600,
#           'mobile':  0,
#           onExperienceDefined: function( experience ) {}
#         },
#         adblock: {
#           blocked_class: 'plundered',
#           bait_class:    'ad_container afs_ads afs_ads_dt',
#           bait_style:    'width:300px; height:250px; position:absolute; left:11111px; top:111px; pointer-events:none;',
#           bait_select:   'afs_ads_dt',
#           init:          function( experience ) {},
#           onCaughtBait:  function( is_blocked, self ) {}
#         },
#         injector: {
#           content_target:  '#container',
#           inject_target:   '.dtads-inject-hook',
#           slot_type:       'mpu',
#           skip_targets:    ['alignleft', 'alignright'],
#           // opportunity to hand filter potential elements to parse through, must return back array of elements
#           // filterPotentials: function( _potentials, experience ) { return _potentials; },
#           options: {
#             desktop: {
#               start_index:         1,
#               look_back:           2,
#               look_ahead:          3,
#               skip_ahead:          10,
#               max_ads:             4,
#               min_good_length:     400,
#               min_content_length:  1100
#             },
#             tablet: {
#               start_index:         2,
#               look_back:           2,
#               look_ahead:          3,
#               skip_ahead:          7,
#               max_ads:             4,
#               min_good_length:     400,
#               min_content_length:  900
#             },
#             mobile: {
#               start_index:         1,
#               look_back:           1,
#               look_ahead:          2,
#               skip_ahead:          4,
#               max_ads:             8,
#               min_good_length:     140,
#               min_content_length:  500
#             }
#           }
#         },
#         ads: {
#           unit_name:        '/5611/boinboing',
#           demo_unit_name:   '/5611/boinboing',
#           lazy:             false,
#           lazy_mod:         140,
#           refresh_in_view:  true,
#           slot_args: {
#             "out_of_page": {
#               "class": "dtads-out-of-page",
#               "keyvals": {
#                 "type": "roadblock"
#               }
#             },
#             "leaderboard": { // mapLeaderboard
#               "class": "dtads-slot-leaderboard",
#               "sizes": [
#                 [728, 90],
#                 [970, 90],
#                 [300, 50],
#                 [320, 50]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf",
#               }
#             },
#             "leaderboard_square": { // mapLeaderboardSquare
#               "class": "dtads-slot-leaderboardsquare",
#               "sizes": [
#                 [728, 90],
#                 [970, 90],
#                 [300, 250]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf",
#               }
#             },
#             "leaderboard_tablet": {
#               "class": "dtads-slot-leaderboard-tablet",
#               "sizes": [
#                 [728, 90],
#                 [728, 230]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "mpu": { // mapDesktopSidebar
#               "class": "dtads-slot-mpu",
#               "sizes": [
#                 [300, 250],
#                 [300, 600]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "feature_footer": { // mapDesktopSquare3
#               "class": "dtads-slot-feature-footer",
#               "sizes": [
#                 [300, 300],
#                 [300, 445]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "blog_footer": { // mapDesktopSquare1
#               "class": "dtads-slot-blog-footer",
#               "sizes": [
#                 [125, 125],
#                 [125, 275],
#                 [300, 250]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "mobile_sidebar": {  // mapMobileSidebar
#               "class": "dtads-slot-mobile-sidebar",
#               "sizes": [
#                 [320, 50],
#                 [300, 250]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "bigtop": {
#               "class": "dtads-slot-bigtop",
#               "sizes": [
#                 [1400, 600]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             }
#           },
#           keyvals: {
#             "aid":   1234567,
#             "tags":  [],
#             "cat":   [],
#           },
#           // onAdsReady: () => {},
#           //last chance to manipulate configuration of gpt
#           handleGPT: () => {
#             //window.googletag.pubads().setTargeting(...);
#                     googletag.pubads().setTargeting('is_home', 'yes');
#         googletag.pubads().setTargeting('is_testing', 'no');
#
#             googletag.pubads().setCentering(true);
#             // googletag.pubads().collapseEmptyDivs();
#             // googletag.pubads().enableSingleRequest();
#             // googletag.enableServices();
#           },
#           bigtop: {
#             enabled: true,
#             //must pass reference to Barkeep
#             barkeep: window.Barkeep,
#             //only allow bigtops on these experiences
#             allowed_experiences: [
#               'desktop',
#               'tablet',
#               'mobile'
#             ],
#             //max width before scaling happens
#             max_width: 1920,
#             //max height of bigtop
#             max_height: 500,
#             //min width of bigtop, will default to width of body
#             min_width: null
#           },
#           supports: {
#             "desktop": ["bt","bt2"],
#             "tablet":[],
#             "mobile":[]
#           }
#         },
#         pre: {
#           enable: true,
#           enable_refresh: true,
#           timeout: 600,
#           refresh_timeout: 500,
#           onBidTimeout: function(module, data) {
#               if (data === 'timeout') {}
#           },
#           prebid: {
#             enable: true,
#             enable_refresh: true,
#             config: 'boingboing'
#           }
#         }
#       };
#
#       var _script = document.createElement('script');
#       _script.onload = function() {
#         console.log('Burnside Loaded');
#         Burnside = new _Burnside(_args);
#       };
#
#       _script.src = url;
#       _head.appendChild(_script);
#     };
#
#     _script.src = url;
#     document.head.appendChild(_script);
#     //End of DT Burnside
#   })();
#   </script>
#
#     <!-- UnrulyX tag -->
#   <script>var unruly=window.unruly || {};unruly.native=unruly.native || {};unruly.native.siteId=1021419;</script>
#   <script src="//video.unrulymedia.com/native/native-loader.js"></script>
#
#   <!-- DistroScale begin -->
#   <script async type="text/javascript" src="//c.jsrdn.com/s/cs.js?p=22428"></script>
#   <div id="ds_default_anchor"></div>
#   <!-- DistroScale end -->
#
#   <!-- Facebook Pixel Code -->
#   <script>!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init', '1174428159312267');fbq('track', 'PageView');</script>
#   <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1174428159312267&ev=PageView&noscript=1" /></noscript>
#   <!-- DO NOT MODIFY -->
#   <!-- End Facebook Pixel Code -->
#
#   <!-- cedato -->
#   <script>
#     googletag.cmd.push(function() {
#       googletag.defineSlot('/5611/Cedato_for_BoingBoing', [[1, 1], [1400, 600]], 'div-gpt-ad-1532473794430-0').addService(googletag.pubads());
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
#
#   <!-- battleforthenet.com -->
#   <!-- <script src="https://redalert.battleforthenet.com/widget.js" async></script> -->
#   <!-- end battleforthenet.com -->
#
#   <!-- END OF AD CODE -->
#
#
# </head>
#
# <body class="home page-template page-template-homepage page-template-homepage-php page page-id-421667">
# <!-- /5611/Cedato_for_BoingBoing -->
# <div id='div-gpt-ad-1532473794430-0'>
# 	<script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1532473794430-0');});</script>
# </div>
#
# <div id="container">
#
# 	<div class="navbyline homepage">
# 		<span class="logo"><a href="https://boingboing.net"><img src="https://media.boingboing.net/wp-content/themes/bng/i/logo.png"></a></span> /
# 		<span id="submit"><a href="http://boingboing.net/sub">SUBMIT</a></span> /
# 		<span class="date"  onclick="document.getElementById('metadata').style.display='inline';"><a href="https://boingboing.net/search">SEARCH</a></span>  /
# 		<span id="store" style=""><a href="https://store.boingboing.net">STORE</a> / </span>
# 		<span id="menu" style=""><a href="javascript:void(0)" onclick="showmenu()">MENU</a></span>
# 		<div id="menuitems">
# 			<li><a href="http://boingboing.net/blog">Blog</a> : Show me posts</li>
# 			<li><a href="http://bbs.boingboing.net">Forums</a> : Read the <a href="https://bbs.boingboing.net/faq">rules</a></li>
# 			<li><a href="http://store.boingboing.net">Shop</a> : Wonderful Products <a href="mailto:pubsupport@stackcommerce.com">(Email Support)</a></li>
# 			<li><a href="http://boingboing.net/about">About Us</a> : Writers and staff</li>
# 			<li><a href="http://boingboing.net/contact">Contact Us</a> : Get satisfaction</li>
#
# 			<li><a href="http://boingboing.net/advertise">Advertise</a> : Thank you for reading</li>
# 			<li><a href="http://boingboing.net/privacy">Privacy Policy</a> : The data you generate</li>
# 			<li><a href="http://boingboing.net/tos">TOS</a> : What you agree to</li>
# 			<li></li>
# 		</div>
#
# 	</div>
#
#
#
#
# <div id="leaderboard">
# 	<!-- /5611/boinboing -->
# 	<div id="Homepage_Leaderboard" class="dtads-slot-leaderboard dtads-desktop dtads-tablet"></div>
# 	<div id="Homepage_Mobile_1" class="dtads-slot-mobile-sidebar dtads-mobile"></div>
# </div>
#
#
# <div id="slots">
#
# <div class="feature top" style="" >
# 	<a href="https://boingboing.net/2018/09/08/trump-planned-venezuela-coup.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2017/11/trump-mouth.jpg?ssl=1')">
#
# 			</div>
# 	</a>
# 	<h2>
# 		<a class="tag" style="color:#dd859;" href="https://boingboing.net/tag/war">
# 			war		</a>
# 		<a class="headline" href="https://boingboing.net/2018/09/08/trump-planned-venezuela-coup.html">
# 			Trump planned Venezuela coup, inasmuch he is capable of "planning" anything		</a>
# 		<a class="byline" href="https://boingboing.net/author/rob_beschizza">
# 			<br>Rob&nbsp;Beschizza		</a>
# 	</h2>
# 	</div><div class="feature" style="" >
# 	<a href="https://boingboing.net/2018/09/08/fitness-youtuber-breaks-down-j.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/fitness-marshall-01.jpg?ssl=1')">
#
# 			</div>
# 	</a>
# 	<h2>
# 		<a class="tag" style="color:#2.1805;" href="https://boingboing.net/tag/recording-industry">
# 			recording industry		</a>
# 		<a class="headline" href="https://boingboing.net/2018/09/08/fitness-youtuber-breaks-down-j.html">
# 			Fitness YouTuber breaks down just how little he makes		</a>
# 		<a class="byline" href="https://boingboing.net/author/andrea_james_1">
# 			<br>Andrea&nbsp;James		</a>
# 	</h2>
# 	</div><div class="feature" style="margin-right:0;" >
# 	<a href="https://boingboing.net/2018/09/08/a-candle-that-smells-like-chin.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Chinese-takeout-food-candle.jpg?ssl=1')">
#
# 			</div>
# 	</a>
# 	<h2>
# 		<a class="tag" style="color:#45dd30;" href="https://boingboing.net/tag/Chinese-food">
# 			Chinese food		</a>
# 		<a class="headline" href="https://boingboing.net/2018/09/08/a-candle-that-smells-like-chin.html">
# 			A candle that smells like Chinese takeout		</a>
# 		<a class="byline" href="https://boingboing.net/author/blazenhoff_1">
# 			<br>Rusty&nbsp;Blazenhoff		</a>
# 	</h2>
# 	</div>
# </div> <!-- end slots -->
#
#
#
#
# <div id="features">
#
# 	<div id="sidebar">
#
#
#
#
# 	<div class="ad ad300">
# 		<!-- /5611/boinboing -->
# 		<div id="Homepage_300x250_300x600_1" class="dtads-slot-mpu dtads-desktop dtads-tablet"> </div>
# 	</div>
#
# <div id="widgets">
# 	<div id="stackcommerce_widget-2" class="sidebarbox widget widget_stackcommerce_widget"><h3>From the Boing Boing Shop</h3>        <div class="stackCommerceWidgetSidebar vertical2"
#              data-sc-hide-price=""
#              data-sc-hide-ribon=""
#              data-sc-hide-button=""
#              data-sc-column-count="2"
#              data-sc-view-design="2"
#              data-sc-widget="1"
#              data-sc-widget-title="Right Sidebar"
#              data-sc-image-width="50"
#              data-sc-publisher-id="107"
#              data-sc-sort="best_sellers"
#              data-sc-per-page="5"
#              data-sc-header-color="#FF3131"
#              data-sc-title-sizes="14"
#              data-sc-open-new-tab="on"
#              data-sc-utm="boingboing.net"
#              data-sc-utm-medium=""
#              data-sc-utm-additional=""
#              data-sc-affiliate-id=""
#              data-sc-medium-item-name="1"
#         >
#         </div>
#         <div class="allDealsLink stackCommerceSeeAllDeals">
#             <a target='_blank'                href="#">
#                 See all deals            </a>
#         </div>
#         <div class="stackCommerceHelper"></div>
#         </div></div>
#
#
# 	<div class="ad ad300">
# 		<!-- /5611/boinboing -->
# 		<div id="Homepage_300x250_300x600_2" class="dtads-slot-mpu dtads-desktop dtads-tablet"></div>
# 	</div>
#
# 	<div class="ad ad300 stickme">
# 		<div id="followbb" class="sidebarbox">
# 			<h3>Follow Us</h3>
# 			<h4><a class="twitter" href="http://twitter.com/boingboing">Twitter</a> /
# 				 <a class="facebook" href="https://www.facebook.com/boingboing">Facebook</a> /
# 				 <a class="rss" href="http://boingboing.net/feed">RSS</a>
# 			</h4>
# 		</div>
# 	</div>
#
# </div>
#
# 	<div id="content">
#
#
#
#
# <div id="latestposts">
#
#
#
#
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/08/george-zimmerman-threatened-to.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2016/05/zimmermanpainting21-1150x647.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#6477dd;" href="https://boingboing.net/tag/trayvon">
# 					trayvon				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/george-zimmerman-threatened-to.html">
# 					George Zimmerman threatened to feed Beyoncé and Jay Z to alligators				</a>
# 				<a class="byline" href="https://boingboing.net/author/rob_beschizza">
# 					<br>Rob&nbsp;Beschizza				</a>
# 			</h2>
# 		</div>
#
#
#
#
# 		<div class="morefeatures fromtheshop evens">
# 			<h3>FROM THE <a href="https://store.boingboing.net" style="color:#e00;">BOING BOING STORE</a></h3>
# 			<a href="https://boingboing.net/2018/09/08/why-you-should-build-your-bran.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/08/sale_4574_image-1.jpg?ssl=1')"></div>
# 			</a>
#
# 			<h2>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/why-you-should-build-your-bran.html">
# 					Why you should build your brand with a .tech domain name
# 				</a>
# 			</h2>
# 		</div>
#
#
# 		<div class="morefeatures" style="border-top:0px ;">
#
# 			<a href="https://boingboing.net/2018/09/08/homeless-students.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/th.jpeg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#14dd47;" href="https://boingboing.net/tag/asset-bubbles">
# 					asset bubbles				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/homeless-students.html">
# 					UC Santa Cruz asks professors to rent their spare rooms to students who couldn't get housing guarantees				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures evens" >
#
# 			<a href="https://boingboing.net/2018/09/08/the-mystery-of-tucker-carl.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Screen-Shot-2018-09-08-at-10.46.53-AM.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#18dd95;" href="https://boingboing.net/tag/twerps">
# 					twerps				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/the-mystery-of-tucker-carl.html">
# 					"The Mystery" of Tucker Carlson				</a>
# 				<a class="byline" href="https://boingboing.net/author/rob_beschizza">
# 					<br>Rob&nbsp;Beschizza				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/08/instant-noodle-action-figures.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/taishi-arimura-01.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#51dd81;" href="https://boingboing.net/tag/noodles">
# 					noodles				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/instant-noodle-action-figures.html">
# 					Instant noodle action figures				</a>
# 				<a class="byline" href="https://boingboing.net/author/andrea_james_1">
# 					<br>Andrea&nbsp;James				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures evens" >
#
# 			<a href="https://boingboing.net/2018/09/08/britains-channel-4-highlight.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Screen-Shot-2018-09-08-at-10.15.48-AM.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#37dd22;" href="https://boingboing.net/tag/media">
# 					media				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/britains-channel-4-highlight.html">
# 					Britain's Channel 4 highlights Twitter abuse in ad campaign				</a>
# 				<a class="byline" href="https://boingboing.net/author/rob_beschizza">
# 					<br>Rob&nbsp;Beschizza				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/08/gentleman-extracts-sixth-toile.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/toilet-snakes-01.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#dd1031;" href="https://boingboing.net/tag/non-delightful-creatures">
# 					non-delightful creatures				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/gentleman-extracts-sixth-toile.html">
# 					Gentleman extracts sixth toilet snake in four years				</a>
# 				<a class="byline" href="https://boingboing.net/author/andrea_james_1">
# 					<br>Andrea&nbsp;James				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures evens" >
#
# 			<a href="https://boingboing.net/2018/09/08/infamous-inverted-jenny-st.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/US_Airmail_inverted_Jenny_24c_1918_issue.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#48dd60;" href="https://boingboing.net/tag/stamp">
# 					stamp				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/infamous-inverted-jenny-st.html">
# 					Infamous "Inverted Jenny" Stamp No. 49 resurfaces a century later				</a>
# 				<a class="byline" href="https://boingboing.net/author/andrea_james_1">
# 					<br>Andrea&nbsp;James				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/08/the-playlist-of-the-2018-burni.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Burning-Man-2018-Temple-Burn-by-John-Curley.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#2275dd;" href="https://boingboing.net/tag/DJ-set">
# 					DJ set				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/08/the-playlist-of-the-2018-burni.html">
# 					The playlist of the 2018 Burning Man Temple Burn				</a>
# 				<a class="byline" href="https://boingboing.net/author/blazenhoff_1">
# 					<br>Rusty&nbsp;Blazenhoff				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures evens" >
#
# 			<a href="https://boingboing.net/2018/09/07/x-atencio-r-us.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/050-056c026d-1c66-4d42-9fae-a8e96df290c5-1020x1929-1.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#4.dd31;" href="https://boingboing.net/tag/grim-grinning-ghosts">
# 					grim grinning ghosts				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/x-atencio-r-us.html">
# 					Paper Haunted Mansion music box				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/07/george-papadopoulos-gets-14-da.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/1535591949_96073730_ver1.0_640_480.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#35dd76;" href="https://boingboing.net/tag/coffee-boy">
# 					coffee boy				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/george-papadopoulos-gets-14-da.html">
# 					George Papadopoulos gets 14 days in jail, former Trump campaign adviser must also pay $9,500 fine				</a>
# 				<a class="byline" href="https://boingboing.net/author/ginaloukareas">
# 					<br>Gina&nbsp;Loukareas				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures evens" >
#
# 			<a href="https://boingboing.net/2018/09/07/bug-eyed-monsters.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/l4kwbivfjfovaqbeviws.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#18dd19;" href="https://boingboing.net/tag/inside-jobs">
# 					inside jobs				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/bug-eyed-monsters.html">
# 					Philadelphia science museum employees accused of stealing $50,000 worth of bugs				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/07/pla-vs-appl.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/1536274286386-Screen-Shot-2018-09-06-at-65021-PM.png.jpeg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#dd6702;" href="https://boingboing.net/tag/adware-doctor">
# 					adware doctor				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/pla-vs-appl.html">
# 					The most popular "privacy" tool in Apple's Mac App Store was stealing users' browsing history and sending it to China				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures evens" >
#
# 			<a href="https://boingboing.net/2018/09/07/america-doxed.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/This-is-Equifax.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#2.8042;" href="https://boingboing.net/tag/congress-inaction">
# 					congress inaction				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/america-doxed.html">
# 					It's been a year since Equifax doxed America and nothing's changed				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/07/developers-developers-develope-2.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/source.gif?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#dd9315;" href="https://boingboing.net/tag/if-there-is-hope-it-is-in-the-proles">
# 					if there is hope it is in the proles				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/developers-developers-develope-2.html">
# 					Developers are worth more to tech companies than cash				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures evens" >
#
# 			<a href="https://boingboing.net/2018/09/07/i-just-burnt-an-hour-looking-f.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/61JkrTNIB8L._SL1500_.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#dd6085;" href="https://boingboing.net/tag/Ever-changing-Apple-cable-formats">
# 					Ever changing Apple cable formats				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/i-just-burnt-an-hour-looking-f.html">
# 					I just burnt an hour looking for an old-style iPhone/iPad/iPod cable				</a>
# 				<a class="byline" href="https://boingboing.net/author/jason">
# 					<br>Jason&nbsp;Weisberger				</a>
# 			</h2>
# 		</div>
#
#
#
# 		<div class="morefeatures" >
#
# 			<a href="https://boingboing.net/2018/09/07/los-chicago-boys.html">
# 				<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/kiev-ukraine-december-24-2016-260nw-542262367.jpg?ssl=1')">
#
# 			</div>
# 			</a>
#
# 			<h2>
# 				<a class="tag" style="color:#6.dd21;" href="https://boingboing.net/tag/i-hate-you-ronald-reagan">
# 					i hate you ronald reagan				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/los-chicago-boys.html">
# 					Tim "Net Neutrality" Wu on the case for breaking up Facebook				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 		</div>
# 	</div> <!-- end of latest posts-->
# </div><!-- end of content column-->
# </div> <!-- end of features and latest posts etc-->
#
#
# <!-- /5611/boinboing -->
# 	<div id="Homepage_Mobile_2" class="dtads-slot-mobile-sidebar dtads-mobile"></div>
#
#
# <div class="separator" style="margin:1em auto 2em auto;border:4px solid red;padding:1em;max-width:1000px;text-align:center;">
#
# <!-- Begin MailChimp Signup Form -->
# <link href="//cdn-images.mailchimp.com/embedcode/horizontal-slim-10_7.css" rel="stylesheet" type="text/css">
# <style type="text/css">
# 	#mc_embed_signup{background:#fff; clear:left; font:14px Helvetica,Arial,sans-serif; width:100%;}
# </style>
# <style type="text/css">
# 	#mc-embedded-subscribe-form input[type=checkbox]{display: inline; width: auto;margin-right: 10px;}
# 	#mergeRow-gdpr {margin-top: 20px;}
# 	#mergeRow-gdpr fieldset label {font-weight: normal;}
# 	#mc-embedded-subscribe-form .mc_fieldset{border:none;min-height: 0px;padding-bottom:0px;}
#         #mc-embedded-subscribe-form input[type=submit]{background-color: red; color: white;}
# </style>
# <div id="mc_embed_signup">
# <form action="https://boingboing.us2.list-manage.com/subscribe/post?u=0e91f8e7df61da4bff2bd9b1f&amp;id=8c5d27370d" method="post" id="mc-embedded-subscribe-form" name="mc-embedded-subscribe-form" class="validate" target="_blank" novalidate>
#     <div id="mc_embed_signup_scroll">
# 	<label for="mce-EMAIL">GET THE BOING BOING NEWSLETTER</label>
# 	<input type="email" value="" name="EMAIL" class="email" id="mce-EMAIL" placeholder="email address" required>
#     <div style="position: absolute; left: -5000px;" aria-hidden="true"><input type="text" name="b_0e91f8e7df61da4bff2bd9b1f_8c5d27370d" tabindex="-1" value=""></div>
#     <div class="clear"><input type="submit" value="Subscribe" name="subscribe" id="mc-embedded-subscribe" class="button"></div>
#     </div>
# </form>
# </div>
#
# <!--End mc_embed_signup-->
# </div>
#
#
#
#
# <div id="posts">
#
#
#
# <div class="feature"  >
# 		<a href="https://boingboing.net/2018/09/07/lipstick-for-ugly-ugly-pigs.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/og-copyrightbot-hd_0-1-1.png?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#23dd99;" href="https://boingboing.net/tag/axl-voss">
# 					axl voss				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/lipstick-for-ugly-ugly-pigs.html">
# 					The amendments for the EU's catastrophic copyright proposals don't fix a goddamned thing				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 	</div><div class="feature" style="margin-right:0" >
# 		<a href="https://boingboing.net/2018/09/07/it-pays-to-haggle-over-your-ca.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/shutterstock_519608041.jpg?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#10dd76;" href="https://boingboing.net/tag/saving-money">
# 					saving money				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/it-pays-to-haggle-over-your-ca.html">
# 					It pays to haggle over your cable TV contract, says Consumer Reports				</a>
# 				<a class="byline" href="https://boingboing.net/author/mark_frauenfelder_1">
# 					<br>Mark&nbsp;Frauenfelder				</a>
# 			</h2>
# 	</div><div class="feature"  >
# 		<a href="https://boingboing.net/2018/09/07/free-wechat.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/f32.png?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#dd563;" href="https://boingboing.net/tag/ocr">
# 					ocr				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/free-wechat.html">
# 					How to: beat Chinese social media image-filtering				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 	</div><div class="feature"  >
# 		<a href="https://boingboing.net/2018/09/07/destiny-2-foresaken-may-be-to.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/0-2.jpg?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#dd495;" href="https://boingboing.net/tag/byf">
# 					byf				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/destiny-2-foresaken-may-be-to.html">
# 					Destiny 2: Forsaken may be too confusing to bother re-engaging with				</a>
# 				<a class="byline" href="https://boingboing.net/author/jason">
# 					<br>Jason&nbsp;Weisberger				</a>
# 			</h2>
# 	</div><div class="feature" style="margin-right:0" >
# 		<a href="https://boingboing.net/2018/09/07/trump-justice-dept-should-inv.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/tr.jpg?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#dd2543;" href="https://boingboing.net/tag/freedom-of-the-press">
# 					freedom of the press				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/trump-justice-dept-should-inv.html">
# 					Trump: Justice Dept should investigate identity of anonymous NY Times op-ed writer, because national security				</a>
# 				<a class="byline" href="https://boingboing.net/author/xeni_jardin">
# 					<br>Xeni&nbsp;Jardin				</a>
# 			</h2>
# 	</div><div class="feature"  >
# 		<a href="https://boingboing.net/2018/09/07/video-a-fun-burning-man-2018.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/maxresdefault-1.jpg?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#1824dd;" href="https://boingboing.net/tag/hyperlapse">
# 					hyperlapse				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/video-a-fun-burning-man-2018.html">
# 					Video: A fun Burning Man 2018 hyperlapse with lots of lovely robots				</a>
# 				<a class="byline" href="https://boingboing.net/author/xeni_jardin">
# 					<br>Xeni&nbsp;Jardin				</a>
# 			</h2>
# 	</div><div class="feature"  >
# 		<a href="https://boingboing.net/2018/09/07/sharing-is-caring-2.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/SYIActionWeekWebBanner.png?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#6.2568;" href="https://boingboing.net/tag/#saveyourinternet">
# 					#saveyourinternet				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/sharing-is-caring-2.html">
# 					Creative Commons: next week's EU vote could cost us the internet				</a>
# 				<a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# 					<br>Cory&nbsp;Doctorow				</a>
# 			</h2>
# 	</div><div class="feature" style="margin-right:0" >
# 		<a href="https://boingboing.net/2018/09/07/nazi-puncher-fined-1.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/nazi-puncher-01.jpg?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#42dd63;" href="https://boingboing.net/tag/extremism">
# 					extremism				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/nazi-puncher-fined-1.html">
# 					Nazi-puncher fined $1				</a>
# 				<a class="byline" href="https://boingboing.net/author/andrea_james_1">
# 					<br>Andrea&nbsp;James				</a>
# 			</h2>
# 	</div><div class="feature"  >
# 		<a href="https://boingboing.net/2018/09/07/academic-freedom-grifters-rall.html">
# 			<div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Dumpster_Fire_3968047605.jpg?ssl=1')">
# 							</div>
# 		</a>
# 			<h2>
# 				<a class="tag"  style="color:#dd6833;" href="https://boingboing.net/tag/Retraction-Watch">
# 					Retraction Watch				</a>
# 				<a class="headline" href="https://boingboing.net/2018/09/07/academic-freedom-grifters-rall.html">
# 					Academic freedom grifters rally around a new anti-transgender "disease"				</a>
# 				<a class="byline" href="https://boingboing.net/author/andrea_james_1">
# 					<br>Andrea&nbsp;James				</a>
# 			</h2>
# 	</div>
#
# </div> <!--posts end-->
# <a style="color:white;" href="https://boingboing.net/grid/page/2/">
# 	<h1 class="exhort">NEXT</h1>
# </a>
# </div> <!--container end-->
#
# <div id=”pmAdTag”><!-- Positive Mobile ad --></div>
#
# <p>
#
# <div id="footer" class="clearfix">
#
#     <div id="footer-left">
#         <p>Read the rules you agree to by using this website in our <a href="http://boingboing.net/tos">Terms of Service</a>.</p>
# 				<p>We are a participant in the Amazon Services LLC Associates Program, an affiliate advertising program designed to provide a means for us to earn fees by linking to Amazon.com and affiliated sites.</p>
# 				<p>Boing Boing uses cookies and analytics trackers, and is supported by advertising, merchandise sales and affiliate links. Read about what we do with the data we gather in our <a href="http://boingboing.net/privacy">Privacy Policy</a>.</p>
# 				<p>Who will be eaten first? Our forum rules are detailed in the <a href="http://bbs.boingboing.net/faq">Community Guidelines</a>.</p>
# 				<p>Boing Boing is published under <a href="http://creativecommons.org/licenses/by-nc-sa/3.0/deed.en_US">a Creative Commons license</a> except where otherwise noted.</p>
#     </div>
#
#     <div id="footer-middle">
#     </div>
#
#      <div id="footer-right">
#       <p>		<a href="http://twitter.com/frauenfelder">Mark Frauenfelder
#      	<br>	<a href="http://twitter.com/doctorow">Cory Doctorow
#      	<br>	<a href="http://twitter.com/pesco">David Pescovitz
#      	<br>	<a href="http://twitter.com/xeni">Xeni Jardin
#      	<br>	<a href="http://twitter.com/beschizza">Rob Beschizza</p>
#
#      	<p class="staff"><a href="http://twitter.com/jlw">Jason Weisberger</a><br><span class="job">Publisher</span></p>
#      	<p class="staff"><a href="http://twitter.com/orenwolf">Ken Snider</a><br><span class="job">Sysadmin</span></p>
#
#    		<p>		<a href="https://boingboing.net/about">About Us</a>
# 			<br>	<a href="https://boingboing.net/contact">Contact Us</a>
# 			<br>	<a href="https://boingboing.net/advertise">Advertise</a>
# 			<br>	<a href="http://bbs.boingboing.net">Forums</a>
# 			<br>	<a href="http://store.boingboing.net">Shop</a>
# 			<br>	<a href="mailto:pubsupport@stackcommerce.com">Shop Support</a></p>
#      </div>
# </div>
#
# <script type='text/javascript' src='https://media.boingboing.net/wp-includes/js/wp-embed.min.js?ver=4.9.8'></script>
# <script type='text/javascript' src='https://media.boingboing.net/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='https://media.boingboing.net/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript' src='https://widgets.stackcommerce.com/deal-feed/stackCommerceWidget-v2.min.js'></script>
# <!-- Jetpack Google Analytics -->
# 			<script type='text/javascript'>
# 				var _gaq = _gaq || [];
# 				_gaq.push(['_setAccount', 'UA-3839311-1']);
# _gaq.push(['_trackPageview']);
# 				(function() {
# 					var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 					ga.src = ('https:' === document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 					var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 				})();
# 			</script>
# <link rel='stylesheet' id='contact-form-7-css'  href='https://media.boingboing.net/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.0.4' type='text/css' media='all' />
# <link rel='stylesheet' id='custom-style-css'  href='https://media.boingboing.net/wp-content/plugins/stackcommerce-deal-feed/wp/includes/css/custom_script.css?ver=4.9.8' type='text/css' media='all' />
# <style id='custom-style-inline-css' type='text/css'>
#
#                 .stackCommerceWidgetSidebar .singlestackCommerceItem .stackCommerceItemPrice{
#                         background: #e2e2e2;
#                         color: #ffffff;
#                 }
#                 .stackCommerceWidgetSidebar .singlestackCommerceItem {
#                     background: #ffffff;
#                 }
#                 .stackCommerceWidgetSidebar .singlestackCommerceItem .singlestackCommerceItemDiscount {
#                     background: #eeee22;
#                     color: #dd3333;
#                     display: block;
#                 }
#                 .stackCommerceSeeAllDeals {
#                     display: block;
#                 }
#                 .stackCommerceInlineDisplayHeader .stackCommerceInlineHeaderText {
#                     font-size: 40px;
#                 }
#                 .singlestackCommerceItem {
#                     background: #ffffff;
#                 }
#                                                                                                                                                                                                                                                                                                                                                                                        .stackCommerceWidgetSidebar {
#
#     background-color: white;margin-bottom:1em; }
#                                                                                      .stackCommerceWidgetSidebar .singlestackCommerceItem .stackCommerceItemTitle a {
#     color: #000;background-color:white;}
#
#  .stackCommerceSeeAllDeals {
#     display: block;
#     font-family: raleway;
#     color: blue;
#     font-weight: bold;
#     margin: 10px;
# }
#
# .page {
# width: 100%; float: left;
# }
#
#
# .stackCommerceItemImage img {
# margin:0 !important;
# }
# </style>
# <link rel='stylesheet' id='dashicons-css'  href='https://media.boingboing.net/wp-includes/css/dashicons.min.css?ver=4.9.8' type='text/css' media='all' />
# <link rel='stylesheet' id='jetpack-widget-social-icons-styles-css'  href='https://media.boingboing.net/wp-content/plugins/jetpack/modules/widgets/social-icons/social-icons.css?ver=20170506' type='text/css' media='all' />
# <script type='text/javascript' src='https://media.boingboing.net/wp-content/plugins/jetpack/_inc/build/photon/photon.min.js?ver=20130122'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/boingboing.net\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://media.boingboing.net/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.0.4'></script>
# <script type='text/javascript' src='https://s0.wp.com/wp-content/js/devicepx-jetpack.js?ver=201836'></script>
# <script type='text/javascript' src='https://stats.wp.com/e-201836.js' async='async' defer='defer'></script>
# <script type='text/javascript'>
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:6.5',blog:'87954168',post:'421667',tz:'-7',srv:'boingboing.net'} ]);
# 	_stq.push([ 'clickTrackerInit', '87954168', '421667' ]);
# </script>
# <script>jQuery(function(){jQuery('#sidebar').height(jQuery('#features').height())});</script>
#
# <!-- Analytics-->
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-QX6JKE-6M4Jf7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-QX6JKE-6M4Jf7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
#
#
# <!-- Google Analytics include -->
# <script>
# function clickTrack(url, action, label){
#     if(url && action && label){
#         clickedURL = url;
#         if(typeof(event) != "undefined") event.returnValue = false;
#         ga('send', 'event', {
#             'eventCategory' : 'UI Click',
#             'eventAction'   : action,
#             'eventLabel'    : label,
#             'hitCallback'   : function () {
#                 document.location = clickedURL;
#             }
#         });
#         return false;
#     }
#     return true;
# }
# </script>
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-3839311-1', 'auto');
#
#
#   ga('send', 'pageview');
#
# </script>
# <!-- end Google Analytics include -->
#
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "7518287" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript><img src="http://b.scorecardresearch.com/p?c1=2&c2=7518287&cv=2.0&cj=1" /></noscript>
# <!-- End comScore Tag -->
#
# <script>
# 		function showmenu() {
# 			var currentHeight = document.getElementById("menuitems").style.height;
# 			if (currentHeight == "250px") {
# 				document.getElementById("menuitems").style.height = "0px";
# 			} else {
# 				document.getElementById("menuitems").style.height = "250px";
# 			}
# 		}
# </script>
# <script src="https://tags.crwdcntrl.net/c/8753/cc_af.js"></script>
#
# <script>
#     function createCookie(name,value,days) {
#     var expires;
#     if (days) {
#         var date = new Date();
#         date.setTime(date.getTime()+(days*24*60*60*1000));
#         expires = "; expires="+date.toGMTString();
#     }
#     else {
#         expires = "";
#     }
#     document.cookie = name+"="+value+expires+"; path=/";
# }
#
# function readCookie(name) {
#     var nameEQ = name + "=";
#     var ca = document.cookie.split(';');
#     for(var i=0;i < ca.length;i++) {
#         var c = ca[i];
#         while (c.charAt(0)==' ') c = c.substring(1,c.length);
#         if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
#     }
#     return null;
# }
#
# var BNGEnqueueMC = readCookie('BNGEnqueueMC');
#
# if( 'yes' === BNGEnqueueMC ) {
#     // Embed scripts
#     var mc1 = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#     mc1.src = '//downloads.mailchimp.com/js/signup-forms/popup/embed.js';
#     mc1.setAttribute('data-dojo-config', 'usePlainJson: true, isDebug: false');
#     el.parentNode.insertBefore(mc1, el);
#     var mcInterval = setInterval(function(){
#         if( 'function' === typeof PopupSignupForm) {
#           require(["mojo/signup-forms/Loader"], function(L) { L.start({"baseUrl":"mc.us2.list-manage.com","uuid":"0e91f8e7df61da4bff2bd9b1f","lid":"8c5d27370d"}) });
#           clearInterval(mcInterval);
#         }
#     }, 250);
# } else {
#     createCookie('BNGEnqueueMC', 'yes', 30);
# }
# </script>
#
#
# </body>

# %%
soup = BeautifulSoup(data,'lxml')
print(soup)
# BeautifulSoup(data,'lxml') is setting up a parser to scan the data
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>Boing Boing - A Directory of Mostly Wonderful Things</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.5.18/webfont.js"></script>
# <script>
#   WebFont.load({
#     google: {
#       families: ['Raleway:600,800,400','Libre+Baskerville:400,700,400italic']
#     }
#   });
# </script>
# <link href="https://media.boingboing.net/wp-content/themes/bng/style.css?=v1" media="all" rel="stylesheet" type="text/css"/>
# <!-- Jetpack Site Verification Tags -->
# <meta content="2Z2CdDZoCt3kedjrHnPrbA3HjYnoXwwgy2pjFo552ws" name="google-site-verification"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://boingboing.net/feed" rel="alternate" title="Boing Boing » Feed" type="application/rss+xml"/>
# <link href="https://boingboing.net/comments/feed" rel="alternate" title="Boing Boing » Comments Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/boingboing.net\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://media.boingboing.net/wp-content/plugins/jetpack/css/jetpack.css?ver=6.5" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://boingboing.net/wp-json/" rel="https://api.w.org/"/>
# <link href="https://boingboing.net/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://media.boingboing.net/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 4.9.8" name="generator"/>
# <link href="https://boingboing.net/" rel="canonical"/>
# <link href="https://boingboing.net/" rel="shortlink"/>
# <link href="https://boingboing.net/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fboingboing.net%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://boingboing.net/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fboingboing.net%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <link href="//i0.wp.com" rel="dns-prefetch"/>
# <link href="//i1.wp.com" rel="dns-prefetch"/>
# <link href="//i2.wp.com" rel="dns-prefetch"/>
# <style type="text/css">img#wpstats{display:none}</style><meta content="Brain candy for Happy Mutants" name="description"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="website" property="og:type"/>
# <meta content="Boing Boing" property="og:title"/>
# <meta content="Brain candy for Happy Mutants" property="og:description"/>
# <meta content="https://boingboing.net/" property="og:url"/>
# <meta content="Boing Boing" property="og:site_name"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="Homepage" name="twitter:text:title"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@boingboing" name="twitter:site"/>
# <meta content="https://media.boingboing.net/wp-content/themes/bng/i/placeholder.png" property="og:image"/>
# <meta content="1600" property="og:image:width"/>
# <meta content="900" property="og:image:height"/>
# <meta content="https://media.boingboing.net/wp-content/themes/bng/i/placeholder.png" name="twitter:image"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=32%2C32&amp;ssl=1" rel="icon" sizes="32x32"/>
# <link href="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=158%2C158&amp;ssl=1" rel="icon" sizes="192x192"/>
# <link href="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=158%2C158&amp;ssl=1" rel="apple-touch-icon-precomposed"/>
# <meta content="https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/04/apple-touch-icon-1.png?fit=158%2C158&amp;ssl=1" name="msapplication-TileImage"/>
# <script>
#   (function (s,o,n,a,r,i,z,e) {s['StackSonarObject']=r;s[r]=s[r]||function(){
#   (s[r].q=s[r].q||[]).push(arguments)},s[r].l=1*new Date();i=o.createElement(n),
#   z=o.getElementsByTagName(n)[0];i.async=1;i.src=a;z.parentNode.insertBefore(i,z)
#   })(window,document,'script','https://www.stack-sonar.com/ping.js','stackSonar');
#
#   stackSonar('stack-connect-wp', "6Mp0z_hYN4uKoN7SaPiUOQ");
# </script>
# <!-- AD CODE -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#
#   var pageType = 'Homepage'; // Targeting to 'Feature' or 'Homepage' or 'Blog'
#
#   // Barkeep
#   (function() {
#     var url = '//burnside.dtcn.com/barkeep/barkeep.min.js';
#     var args = {
#       //main container of all bars
#       //if no container is found, one is made with the given selector
#       //all pints are collected and maintained within this one container
#       container_sel:   'h-bartender',
#       //target bars by this class
#       pint_bar_class:  'h-pint',
#       //first wrapper element class name, used for positioning
#       pint_pos_class:  'm-pint-pos',
#       //second wrapper element class name (this will be the outermost container of each bar)
#       pint_wrap_class: 'm-pint-wrap',
#       //class that's appeneded to the pint when in a fixed position
#       fixed_class:     'is-fixed',
#       //class to append when pint is no longer active
#       inactive_class:  'is-dead',
#       //default bar type (static | fixed)
#       bar_type:        'static' ,
#       //class to attach close event listener to
#       do_remove_sel:   'h-do-remove-pint',
#       //enable drop shadows on pints
#       drop_shadows:    false,
#       //fires on initialization of obj
#       //passed param is reference to the object itself
#       init: self => {},
#       //fires when pint moves from fixed to static positioning
#       //passed param is the bar element
#       on_bar_down: _bar => {}
#     };
#
#     var _script = document.createElement('script');
#     _script.onload = function() {
#       window.Barkeep = new _Barkeep(args);
#       console.log('Barkeep Loaded');
#
#       var url = '//burnside.dtcn.com/burnside.min.js';
#       var _head = document.head || document.getElementsByTagName('head')[0];
#       var demo_key = 'dtdemo';
#       regex = new RegExp('[\\?&]' + demo_key + '=([a-zA-Z0-9_-]{1,50})');
#       results = regex.exec(window.location.search);
#       var demo = (results) ? decodeURIComponent(results[1]) : '';
#
#       // Burnside
#       var _args = {
#         debug:     false,     // show logs in console
#         demo_key:  demo_key,  // demo targeting key
#         demo_val:  demo,      // demo targeting val, if adblocked, demo_val='adblock'
#         prefix:    'dtads',   // prefix for slots
#         krux_id:   'q7qawfhbx',
#
#         experiences:  {
#           'desktop': 968,
#           'tablet':  600,
#           'mobile':  0,
#           onExperienceDefined: function( experience ) {}
#         },
#         adblock: {
#           blocked_class: 'plundered',
#           bait_class:    'ad_container afs_ads afs_ads_dt',
#           bait_style:    'width:300px; height:250px; position:absolute; left:11111px; top:111px; pointer-events:none;',
#           bait_select:   'afs_ads_dt',
#           init:          function( experience ) {},
#           onCaughtBait:  function( is_blocked, self ) {}
#         },
#         injector: {
#           content_target:  '#container',
#           inject_target:   '.dtads-inject-hook',
#           slot_type:       'mpu',
#           skip_targets:    ['alignleft', 'alignright'],
#           // opportunity to hand filter potential elements to parse through, must return back array of elements
#           // filterPotentials: function( _potentials, experience ) { return _potentials; },
#           options: {
#             desktop: {
#               start_index:         1,
#               look_back:           2,
#               look_ahead:          3,
#               skip_ahead:          10,
#               max_ads:             4,
#               min_good_length:     400,
#               min_content_length:  1100
#             },
#             tablet: {
#               start_index:         2,
#               look_back:           2,
#               look_ahead:          3,
#               skip_ahead:          7,
#               max_ads:             4,
#               min_good_length:     400,
#               min_content_length:  900
#             },
#             mobile: {
#               start_index:         1,
#               look_back:           1,
#               look_ahead:          2,
#               skip_ahead:          4,
#               max_ads:             8,
#               min_good_length:     140,
#               min_content_length:  500
#             }
#           }
#         },
#         ads: {
#           unit_name:        '/5611/boinboing',
#           demo_unit_name:   '/5611/boinboing',
#           lazy:             false,
#           lazy_mod:         140,
#           refresh_in_view:  true,
#           slot_args: {
#             "out_of_page": {
#               "class": "dtads-out-of-page",
#               "keyvals": {
#                 "type": "roadblock"
#               }
#             },
#             "leaderboard": { // mapLeaderboard
#               "class": "dtads-slot-leaderboard",
#               "sizes": [
#                 [728, 90],
#                 [970, 90],
#                 [300, 50],
#                 [320, 50]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf",
#               }
#             },
#             "leaderboard_square": { // mapLeaderboardSquare
#               "class": "dtads-slot-leaderboardsquare",
#               "sizes": [
#                 [728, 90],
#                 [970, 90],
#                 [300, 250]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf",
#               }
#             },
#             "leaderboard_tablet": {
#               "class": "dtads-slot-leaderboard-tablet",
#               "sizes": [
#                 [728, 90],
#                 [728, 230]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "mpu": { // mapDesktopSidebar
#               "class": "dtads-slot-mpu",
#               "sizes": [
#                 [300, 250],
#                 [300, 600]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "feature_footer": { // mapDesktopSquare3
#               "class": "dtads-slot-feature-footer",
#               "sizes": [
#                 [300, 300],
#                 [300, 445]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "blog_footer": { // mapDesktopSquare1
#               "class": "dtads-slot-blog-footer",
#               "sizes": [
#                 [125, 125],
#                 [125, 275],
#                 [300, 250]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "mobile_sidebar": {  // mapMobileSidebar
#               "class": "dtads-slot-mobile-sidebar",
#               "sizes": [
#                 [320, 50],
#                 [300, 250]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             },
#             "bigtop": {
#               "class": "dtads-slot-bigtop",
#               "sizes": [
#                 [1400, 600]
#               ],
#               "keyvals": {
#                 "type": "roadblock",
#                 "loc": "atf"
#               }
#             }
#           },
#           keyvals: {
#             "aid":   1234567,
#             "tags":  [],
#             "cat":   [],
#           },
#           // onAdsReady: () => {},
#           //last chance to manipulate configuration of gpt
#           handleGPT: () => {
#             //window.googletag.pubads().setTargeting(...);
#                     googletag.pubads().setTargeting('is_home', 'yes');
#         googletag.pubads().setTargeting('is_testing', 'no');
#
#             googletag.pubads().setCentering(true);
#             // googletag.pubads().collapseEmptyDivs();
#             // googletag.pubads().enableSingleRequest();
#             // googletag.enableServices();
#           },
#           bigtop: {
#             enabled: true,
#             //must pass reference to Barkeep
#             barkeep: window.Barkeep,
#             //only allow bigtops on these experiences
#             allowed_experiences: [
#               'desktop',
#               'tablet',
#               'mobile'
#             ],
#             //max width before scaling happens
#             max_width: 1920,
#             //max height of bigtop
#             max_height: 500,
#             //min width of bigtop, will default to width of body
#             min_width: null
#           },
#           supports: {
#             "desktop": ["bt","bt2"],
#             "tablet":[],
#             "mobile":[]
#           }
#         },
#         pre: {
#           enable: true,
#           enable_refresh: true,
#           timeout: 600,
#           refresh_timeout: 500,
#           onBidTimeout: function(module, data) {
#               if (data === 'timeout') {}
#           },
#           prebid: {
#             enable: true,
#             enable_refresh: true,
#             config: 'boingboing'
#           }
#         }
#       };
#
#       var _script = document.createElement('script');
#       _script.onload = function() {
#         console.log('Burnside Loaded');
#         Burnside = new _Burnside(_args);
#       };
#
#       _script.src = url;
#       _head.appendChild(_script);
#     };
#
#     _script.src = url;
#     document.head.appendChild(_script);
#     //End of DT Burnside
#   })();
#   </script>
# <!-- UnrulyX tag -->
# <script>var unruly=window.unruly || {};unruly.native=unruly.native || {};unruly.native.siteId=1021419;</script>
# <script src="//video.unrulymedia.com/native/native-loader.js"></script>
# <!-- DistroScale begin -->
# <script async="" src="//c.jsrdn.com/s/cs.js?p=22428" type="text/javascript"></script>
# </head><body><div id="ds_default_anchor"></div>
# <!-- DistroScale end -->
# <!-- Facebook Pixel Code -->
# <script>!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init', '1174428159312267');fbq('track', 'PageView');</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1174428159312267&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- DO NOT MODIFY -->
# <!-- End Facebook Pixel Code -->
# <!-- cedato -->
# <script>
#     googletag.cmd.push(function() {
#       googletag.defineSlot('/5611/Cedato_for_BoingBoing', [[1, 1], [1400, 600]], 'div-gpt-ad-1532473794430-0').addService(googletag.pubads());
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- battleforthenet.com -->
# <!-- <script src="https://redalert.battleforthenet.com/widget.js" async></script> -->
# <!-- end battleforthenet.com -->
# <!-- END OF AD CODE -->
# <!-- /5611/Cedato_for_BoingBoing -->
# <div id="div-gpt-ad-1532473794430-0">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1532473794430-0');});</script>
# </div>
# <div id="container">
# <div class="navbyline homepage">
# <span class="logo"><a href="https://boingboing.net"><img src="https://media.boingboing.net/wp-content/themes/bng/i/logo.png"/></a></span> /
# 		<span id="submit"><a href="http://boingboing.net/sub">SUBMIT</a></span> /
# 		<span class="date" onclick="document.getElementById('metadata').style.display='inline';"><a href="https://boingboing.net/search">SEARCH</a></span>  /
# 		<span id="store" style=""><a href="https://store.boingboing.net">STORE</a> / </span>
# <span id="menu" style=""><a href="javascript:void(0)" onclick="showmenu()">MENU</a></span>
# <div id="menuitems">
# <li><a href="http://boingboing.net/blog">Blog</a> : Show me posts</li>
# <li><a href="http://bbs.boingboing.net">Forums</a> : Read the <a href="https://bbs.boingboing.net/faq">rules</a></li>
# <li><a href="http://store.boingboing.net">Shop</a> : Wonderful Products <a href="mailto:pubsupport@stackcommerce.com">(Email Support)</a></li>
# <li><a href="http://boingboing.net/about">About Us</a> : Writers and staff</li>
# <li><a href="http://boingboing.net/contact">Contact Us</a> : Get satisfaction</li>
# <li><a href="http://boingboing.net/advertise">Advertise</a> : Thank you for reading</li>
# <li><a href="http://boingboing.net/privacy">Privacy Policy</a> : The data you generate</li>
# <li><a href="http://boingboing.net/tos">TOS</a> : What you agree to</li>
# <li></li>
# </div>
# </div>
# <div id="leaderboard">
# <!-- /5611/boinboing -->
# <div class="dtads-slot-leaderboard dtads-desktop dtads-tablet" id="Homepage_Leaderboard"></div>
# <div class="dtads-slot-mobile-sidebar dtads-mobile" id="Homepage_Mobile_1"></div>
# </div>
# <div id="slots">
# <div class="feature top" style="">
# <a href="https://boingboing.net/2018/09/08/trump-planned-venezuela-coup.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2017/11/trump-mouth.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/war" style="color:#dd859;">
# 			war		</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/trump-planned-venezuela-coup.html">
# 			Trump planned Venezuela coup, inasmuch he is capable of "planning" anything		</a>
# <a class="byline" href="https://boingboing.net/author/rob_beschizza">
# <br/>Rob Beschizza		</a>
# </h2>
# </div><div class="feature" style="">
# <a href="https://boingboing.net/2018/09/08/fitness-youtuber-breaks-down-j.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/fitness-marshall-01.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/recording-industry" style="color:#2.1805;">
# 			recording industry		</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/fitness-youtuber-breaks-down-j.html">
# 			Fitness YouTuber breaks down just how little he makes		</a>
# <a class="byline" href="https://boingboing.net/author/andrea_james_1">
# <br/>Andrea James		</a>
# </h2>
# </div><div class="feature" style="margin-right:0;">
# <a href="https://boingboing.net/2018/09/08/a-candle-that-smells-like-chin.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Chinese-takeout-food-candle.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/Chinese-food" style="color:#45dd30;">
# 			Chinese food		</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/a-candle-that-smells-like-chin.html">
# 			A candle that smells like Chinese takeout		</a>
# <a class="byline" href="https://boingboing.net/author/blazenhoff_1">
# <br/>Rusty Blazenhoff		</a>
# </h2>
# </div>
# </div> <!-- end slots -->
# <div id="features">
# <div id="sidebar">
# <div class="ad ad300">
# <!-- /5611/boinboing -->
# <div class="dtads-slot-mpu dtads-desktop dtads-tablet" id="Homepage_300x250_300x600_1"> </div>
# </div>
# <div id="widgets">
# <div class="sidebarbox widget widget_stackcommerce_widget" id="stackcommerce_widget-2"><h3>From the Boing Boing Shop</h3> <div class="stackCommerceWidgetSidebar vertical2" data-sc-affiliate-id="" data-sc-column-count="2" data-sc-header-color="#FF3131" data-sc-hide-button="" data-sc-hide-price="" data-sc-hide-ribon="" data-sc-image-width="50" data-sc-medium-item-name="1" data-sc-open-new-tab="on" data-sc-per-page="5" data-sc-publisher-id="107" data-sc-sort="best_sellers" data-sc-title-sizes="14" data-sc-utm="boingboing.net" data-sc-utm-additional="" data-sc-utm-medium="" data-sc-view-design="2" data-sc-widget="1" data-sc-widget-title="Right Sidebar">
# </div>
# <div class="allDealsLink stackCommerceSeeAllDeals">
# <a href="#" target="_blank">
#                 See all deals            </a>
# </div>
# <div class="stackCommerceHelper"></div>
# </div></div>
# <div class="ad ad300">
# <!-- /5611/boinboing -->
# <div class="dtads-slot-mpu dtads-desktop dtads-tablet" id="Homepage_300x250_300x600_2"></div>
# </div>
# <div class="ad ad300 stickme">
# <div class="sidebarbox" id="followbb">
# <h3>Follow Us</h3>
# <h4><a class="twitter" href="http://twitter.com/boingboing">Twitter</a> /
# 				 <a class="facebook" href="https://www.facebook.com/boingboing">Facebook</a> /
# 				 <a class="rss" href="http://boingboing.net/feed">RSS</a>
# </h4>
# </div>
# </div>
# </div>
# <div id="content">
# <div id="latestposts">
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/08/george-zimmerman-threatened-to.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2016/05/zimmermanpainting21-1150x647.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/trayvon" style="color:#6477dd;">
# 					trayvon				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/george-zimmerman-threatened-to.html">
# 					George Zimmerman threatened to feed Beyoncé and Jay Z to alligators				</a>
# <a class="byline" href="https://boingboing.net/author/rob_beschizza">
# <br/>Rob Beschizza				</a>
# </h2>
# </div>
# <div class="morefeatures fromtheshop evens">
# <h3>FROM THE <a href="https://store.boingboing.net" style="color:#e00;">BOING BOING STORE</a></h3>
# <a href="https://boingboing.net/2018/09/08/why-you-should-build-your-bran.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/08/sale_4574_image-1.jpg?ssl=1')"></div>
# </a>
# <h2>
# <a class="headline" href="https://boingboing.net/2018/09/08/why-you-should-build-your-bran.html">
# 					Why you should build your brand with a .tech domain name
# 				</a>
# </h2>
# </div>
# <div class="morefeatures" style="border-top:0px ;">
# <a href="https://boingboing.net/2018/09/08/homeless-students.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/th.jpeg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/asset-bubbles" style="color:#14dd47;">
# 					asset bubbles				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/homeless-students.html">
# 					UC Santa Cruz asks professors to rent their spare rooms to students who couldn't get housing guarantees				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div>
# <div class="morefeatures evens">
# <a href="https://boingboing.net/2018/09/08/the-mystery-of-tucker-carl.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Screen-Shot-2018-09-08-at-10.46.53-AM.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/twerps" style="color:#18dd95;">
# 					twerps				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/the-mystery-of-tucker-carl.html">
# 					"The Mystery" of Tucker Carlson				</a>
# <a class="byline" href="https://boingboing.net/author/rob_beschizza">
# <br/>Rob Beschizza				</a>
# </h2>
# </div>
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/08/instant-noodle-action-figures.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/taishi-arimura-01.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/noodles" style="color:#51dd81;">
# 					noodles				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/instant-noodle-action-figures.html">
# 					Instant noodle action figures				</a>
# <a class="byline" href="https://boingboing.net/author/andrea_james_1">
# <br/>Andrea James				</a>
# </h2>
# </div>
# <div class="morefeatures evens">
# <a href="https://boingboing.net/2018/09/08/britains-channel-4-highlight.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Screen-Shot-2018-09-08-at-10.15.48-AM.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/media" style="color:#37dd22;">
# 					media				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/britains-channel-4-highlight.html">
# 					Britain's Channel 4 highlights Twitter abuse in ad campaign				</a>
# <a class="byline" href="https://boingboing.net/author/rob_beschizza">
# <br/>Rob Beschizza				</a>
# </h2>
# </div>
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/08/gentleman-extracts-sixth-toile.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/toilet-snakes-01.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/non-delightful-creatures" style="color:#dd1031;">
# 					non-delightful creatures				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/gentleman-extracts-sixth-toile.html">
# 					Gentleman extracts sixth toilet snake in four years				</a>
# <a class="byline" href="https://boingboing.net/author/andrea_james_1">
# <br/>Andrea James				</a>
# </h2>
# </div>
# <div class="morefeatures evens">
# <a href="https://boingboing.net/2018/09/08/infamous-inverted-jenny-st.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/US_Airmail_inverted_Jenny_24c_1918_issue.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/stamp" style="color:#48dd60;">
# 					stamp				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/infamous-inverted-jenny-st.html">
# 					Infamous "Inverted Jenny" Stamp No. 49 resurfaces a century later				</a>
# <a class="byline" href="https://boingboing.net/author/andrea_james_1">
# <br/>Andrea James				</a>
# </h2>
# </div>
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/08/the-playlist-of-the-2018-burni.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Burning-Man-2018-Temple-Burn-by-John-Curley.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/DJ-set" style="color:#2275dd;">
# 					DJ set				</a>
# <a class="headline" href="https://boingboing.net/2018/09/08/the-playlist-of-the-2018-burni.html">
# 					The playlist of the 2018 Burning Man Temple Burn				</a>
# <a class="byline" href="https://boingboing.net/author/blazenhoff_1">
# <br/>Rusty Blazenhoff				</a>
# </h2>
# </div>
# <div class="morefeatures evens">
# <a href="https://boingboing.net/2018/09/07/x-atencio-r-us.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/050-056c026d-1c66-4d42-9fae-a8e96df290c5-1020x1929-1.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/grim-grinning-ghosts" style="color:#4.dd31;">
# 					grim grinning ghosts				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/x-atencio-r-us.html">
# 					Paper Haunted Mansion music box				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div>
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/07/george-papadopoulos-gets-14-da.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/1535591949_96073730_ver1.0_640_480.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/coffee-boy" style="color:#35dd76;">
# 					coffee boy				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/george-papadopoulos-gets-14-da.html">
# 					George Papadopoulos gets 14 days in jail, former Trump campaign adviser must also pay $9,500 fine				</a>
# <a class="byline" href="https://boingboing.net/author/ginaloukareas">
# <br/>Gina Loukareas				</a>
# </h2>
# </div>
# <div class="morefeatures evens">
# <a href="https://boingboing.net/2018/09/07/bug-eyed-monsters.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/l4kwbivfjfovaqbeviws.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/inside-jobs" style="color:#18dd19;">
# 					inside jobs				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/bug-eyed-monsters.html">
# 					Philadelphia science museum employees accused of stealing $50,000 worth of bugs				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div>
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/07/pla-vs-appl.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/1536274286386-Screen-Shot-2018-09-06-at-65021-PM.png.jpeg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/adware-doctor" style="color:#dd6702;">
# 					adware doctor				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/pla-vs-appl.html">
# 					The most popular "privacy" tool in Apple's Mac App Store was stealing users' browsing history and sending it to China				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div>
# <div class="morefeatures evens">
# <a href="https://boingboing.net/2018/09/07/america-doxed.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/This-is-Equifax.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/congress-inaction" style="color:#2.8042;">
# 					congress inaction				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/america-doxed.html">
# 					It's been a year since Equifax doxed America and nothing's changed				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div>
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/07/developers-developers-develope-2.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/source.gif?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/if-there-is-hope-it-is-in-the-proles" style="color:#dd9315;">
# 					if there is hope it is in the proles				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/developers-developers-develope-2.html">
# 					Developers are worth more to tech companies than cash				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div>
# <div class="morefeatures evens">
# <a href="https://boingboing.net/2018/09/07/i-just-burnt-an-hour-looking-f.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/61JkrTNIB8L._SL1500_.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/Ever-changing-Apple-cable-formats" style="color:#dd6085;">
# 					Ever changing Apple cable formats				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/i-just-burnt-an-hour-looking-f.html">
# 					I just burnt an hour looking for an old-style iPhone/iPad/iPod cable				</a>
# <a class="byline" href="https://boingboing.net/author/jason">
# <br/>Jason Weisberger				</a>
# </h2>
# </div>
# <div class="morefeatures">
# <a href="https://boingboing.net/2018/09/07/los-chicago-boys.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/kiev-ukraine-december-24-2016-260nw-542262367.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/i-hate-you-ronald-reagan" style="color:#6.dd21;">
# 					i hate you ronald reagan				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/los-chicago-boys.html">
# 					Tim "Net Neutrality" Wu on the case for breaking up Facebook				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div>
# </div> <!-- end of latest posts-->
# </div><!-- end of content column-->
# </div> <!-- end of features and latest posts etc-->
# <!-- /5611/boinboing -->
# <div class="dtads-slot-mobile-sidebar dtads-mobile" id="Homepage_Mobile_2"></div>
# <div class="separator" style="margin:1em auto 2em auto;border:4px solid red;padding:1em;max-width:1000px;text-align:center;">
# <!-- Begin MailChimp Signup Form -->
# <link href="//cdn-images.mailchimp.com/embedcode/horizontal-slim-10_7.css" rel="stylesheet" type="text/css"/>
# <style type="text/css">
# 	#mc_embed_signup{background:#fff; clear:left; font:14px Helvetica,Arial,sans-serif; width:100%;}
# </style>
# <style type="text/css">
# 	#mc-embedded-subscribe-form input[type=checkbox]{display: inline; width: auto;margin-right: 10px;}
# 	#mergeRow-gdpr {margin-top: 20px;}
# 	#mergeRow-gdpr fieldset label {font-weight: normal;}
# 	#mc-embedded-subscribe-form .mc_fieldset{border:none;min-height: 0px;padding-bottom:0px;}
#         #mc-embedded-subscribe-form input[type=submit]{background-color: red; color: white;}
# </style>
# <div id="mc_embed_signup">
# <form action="https://boingboing.us2.list-manage.com/subscribe/post?u=0e91f8e7df61da4bff2bd9b1f&amp;id=8c5d27370d" class="validate" id="mc-embedded-subscribe-form" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
# <div id="mc_embed_signup_scroll">
# <label for="mce-EMAIL">GET THE BOING BOING NEWSLETTER</label>
# <input class="email" id="mce-EMAIL" name="EMAIL" placeholder="email address" required="" type="email" value=""/>
# <div aria-hidden="true" style="position: absolute; left: -5000px;"><input name="b_0e91f8e7df61da4bff2bd9b1f_8c5d27370d" tabindex="-1" type="text" value=""/></div>
# <div class="clear"><input class="button" id="mc-embedded-subscribe" name="subscribe" type="submit" value="Subscribe"/></div>
# </div>
# </form>
# </div>
# <!--End mc_embed_signup-->
# </div>
# <div id="posts">
# <div class="feature">
# <a href="https://boingboing.net/2018/09/07/lipstick-for-ugly-ugly-pigs.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/og-copyrightbot-hd_0-1-1.png?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/axl-voss" style="color:#23dd99;">
# 					axl voss				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/lipstick-for-ugly-ugly-pigs.html">
# 					The amendments for the EU's catastrophic copyright proposals don't fix a goddamned thing				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div><div class="feature" style="margin-right:0">
# <a href="https://boingboing.net/2018/09/07/it-pays-to-haggle-over-your-ca.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/shutterstock_519608041.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/saving-money" style="color:#10dd76;">
# 					saving money				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/it-pays-to-haggle-over-your-ca.html">
# 					It pays to haggle over your cable TV contract, says Consumer Reports				</a>
# <a class="byline" href="https://boingboing.net/author/mark_frauenfelder_1">
# <br/>Mark Frauenfelder				</a>
# </h2>
# </div><div class="feature">
# <a href="https://boingboing.net/2018/09/07/free-wechat.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/f32.png?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/ocr" style="color:#dd563;">
# 					ocr				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/free-wechat.html">
# 					How to: beat Chinese social media image-filtering				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div><div class="feature">
# <a href="https://boingboing.net/2018/09/07/destiny-2-foresaken-may-be-to.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/0-2.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/byf" style="color:#dd495;">
# 					byf				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/destiny-2-foresaken-may-be-to.html">
# 					Destiny 2: Forsaken may be too confusing to bother re-engaging with				</a>
# <a class="byline" href="https://boingboing.net/author/jason">
# <br/>Jason Weisberger				</a>
# </h2>
# </div><div class="feature" style="margin-right:0">
# <a href="https://boingboing.net/2018/09/07/trump-justice-dept-should-inv.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/tr.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/freedom-of-the-press" style="color:#dd2543;">
# 					freedom of the press				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/trump-justice-dept-should-inv.html">
# 					Trump: Justice Dept should investigate identity of anonymous NY Times op-ed writer, because national security				</a>
# <a class="byline" href="https://boingboing.net/author/xeni_jardin">
# <br/>Xeni Jardin				</a>
# </h2>
# </div><div class="feature">
# <a href="https://boingboing.net/2018/09/07/video-a-fun-burning-man-2018.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i1.wp.com/media.boingboing.net/wp-content/uploads/2018/09/maxresdefault-1.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/hyperlapse" style="color:#1824dd;">
# 					hyperlapse				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/video-a-fun-burning-man-2018.html">
# 					Video: A fun Burning Man 2018 hyperlapse with lots of lovely robots				</a>
# <a class="byline" href="https://boingboing.net/author/xeni_jardin">
# <br/>Xeni Jardin				</a>
# </h2>
# </div><div class="feature">
# <a href="https://boingboing.net/2018/09/07/sharing-is-caring-2.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/SYIActionWeekWebBanner.png?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/#saveyourinternet" style="color:#6.2568;">
# 					#saveyourinternet				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/sharing-is-caring-2.html">
# 					Creative Commons: next week's EU vote could cost us the internet				</a>
# <a class="byline" href="https://boingboing.net/author/cory_doctorow_1">
# <br/>Cory Doctorow				</a>
# </h2>
# </div><div class="feature" style="margin-right:0">
# <a href="https://boingboing.net/2018/09/07/nazi-puncher-fined-1.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i0.wp.com/media.boingboing.net/wp-content/uploads/2018/09/nazi-puncher-01.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/extremism" style="color:#42dd63;">
# 					extremism				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/nazi-puncher-fined-1.html">
# 					Nazi-puncher fined $1				</a>
# <a class="byline" href="https://boingboing.net/author/andrea_james_1">
# <br/>Andrea James				</a>
# </h2>
# </div><div class="feature">
# <a href="https://boingboing.net/2018/09/07/academic-freedom-grifters-rall.html">
# <div class="thumbnailcontainer" style="background-image:url('https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/09/Dumpster_Fire_3968047605.jpg?ssl=1')">
# </div>
# </a>
# <h2>
# <a class="tag" href="https://boingboing.net/tag/Retraction-Watch" style="color:#dd6833;">
# 					Retraction Watch				</a>
# <a class="headline" href="https://boingboing.net/2018/09/07/academic-freedom-grifters-rall.html">
# 					Academic freedom grifters rally around a new anti-transgender "disease"				</a>
# <a class="byline" href="https://boingboing.net/author/andrea_james_1">
# <br/>Andrea James				</a>
# </h2>
# </div>
# </div> <!--posts end-->
# <a href="https://boingboing.net/grid/page/2/" style="color:white;">
# <h1 class="exhort">NEXT</h1>
# </a>
# </div> <!--container end-->
# <div id="”pmAdTag”"><!-- Positive Mobile ad --></div>
# <p>
# </p><div class="clearfix" id="footer">
# <div id="footer-left">
# <p>Read the rules you agree to by using this website in our <a href="http://boingboing.net/tos">Terms of Service</a>.</p>
# <p>We are a participant in the Amazon Services LLC Associates Program, an affiliate advertising program designed to provide a means for us to earn fees by linking to Amazon.com and affiliated sites.</p>
# <p>Boing Boing uses cookies and analytics trackers, and is supported by advertising, merchandise sales and affiliate links. Read about what we do with the data we gather in our <a href="http://boingboing.net/privacy">Privacy Policy</a>.</p>
# <p>Who will be eaten first? Our forum rules are detailed in the <a href="http://bbs.boingboing.net/faq">Community Guidelines</a>.</p>
# <p>Boing Boing is published under <a href="http://creativecommons.org/licenses/by-nc-sa/3.0/deed.en_US">a Creative Commons license</a> except where otherwise noted.</p>
# </div>
# <div id="footer-middle">
# </div>
# <div id="footer-right">
# <p> <a href="http://twitter.com/frauenfelder">Mark Frauenfelder
#      	<br/> </a><a href="http://twitter.com/doctorow">Cory Doctorow
#      	<br/> </a><a href="http://twitter.com/pesco">David Pescovitz
#      	<br/> </a><a href="http://twitter.com/xeni">Xeni Jardin
#      	<br/> </a><a href="http://twitter.com/beschizza">Rob Beschizza</a></p>
# <p class="staff"><a href="http://twitter.com/jlw">Jason Weisberger</a><br/><span class="job">Publisher</span></p>
# <p class="staff"><a href="http://twitter.com/orenwolf">Ken Snider</a><br/><span class="job">Sysadmin</span></p>
# <p> <a href="https://boingboing.net/about">About Us</a>
# <br/> <a href="https://boingboing.net/contact">Contact Us</a>
# <br/> <a href="https://boingboing.net/advertise">Advertise</a>
# <br/> <a href="http://bbs.boingboing.net">Forums</a>
# <br/> <a href="http://store.boingboing.net">Shop</a>
# <br/> <a href="mailto:pubsupport@stackcommerce.com">Shop Support</a></p>
# </div>
# </div>
# <script src="https://media.boingboing.net/wp-includes/js/wp-embed.min.js?ver=4.9.8" type="text/javascript"></script>
# <script src="https://media.boingboing.net/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript"></script>
# <script src="https://media.boingboing.net/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script src="https://widgets.stackcommerce.com/deal-feed/stackCommerceWidget-v2.min.js" type="text/javascript"></script>
# <!-- Jetpack Google Analytics -->
# <script type="text/javascript">
# 				var _gaq = _gaq || [];
# 				_gaq.push(['_setAccount', 'UA-3839311-1']);
# _gaq.push(['_trackPageview']);
# 				(function() {
# 					var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 					ga.src = ('https:' === document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 					var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 				})();
# 			</script>
# <link href="https://media.boingboing.net/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.0.4" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://media.boingboing.net/wp-content/plugins/stackcommerce-deal-feed/wp/includes/css/custom_script.css?ver=4.9.8" id="custom-style-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="custom-style-inline-css" type="text/css">
#
#                 .stackCommerceWidgetSidebar .singlestackCommerceItem .stackCommerceItemPrice{
#                         background: #e2e2e2;
#                         color: #ffffff;
#                 }
#                 .stackCommerceWidgetSidebar .singlestackCommerceItem {
#                     background: #ffffff;
#                 }
#                 .stackCommerceWidgetSidebar .singlestackCommerceItem .singlestackCommerceItemDiscount {
#                     background: #eeee22;
#                     color: #dd3333;
#                     display: block;
#                 }
#                 .stackCommerceSeeAllDeals {
#                     display: block;
#                 }
#                 .stackCommerceInlineDisplayHeader .stackCommerceInlineHeaderText {
#                     font-size: 40px;
#                 }
#                 .singlestackCommerceItem {
#                     background: #ffffff;
#                 }
#                                                                                                                                                                                                                                                                                                                                                                                        .stackCommerceWidgetSidebar {
#
#     background-color: white;margin-bottom:1em; }
#                                                                                      .stackCommerceWidgetSidebar .singlestackCommerceItem .stackCommerceItemTitle a {
#     color: #000;background-color:white;}
#
#  .stackCommerceSeeAllDeals {
#     display: block;
#     font-family: raleway;
#     color: blue;
#     font-weight: bold;
#     margin: 10px;
# }
#
# .page {
# width: 100%; float: left;
# }
#
#
# .stackCommerceItemImage img {
# margin:0 !important;
# }
# </style>
# <link href="https://media.boingboing.net/wp-includes/css/dashicons.min.css?ver=4.9.8" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://media.boingboing.net/wp-content/plugins/jetpack/modules/widgets/social-icons/social-icons.css?ver=20170506" id="jetpack-widget-social-icons-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://media.boingboing.net/wp-content/plugins/jetpack/_inc/build/photon/photon.min.js?ver=20130122" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/boingboing.net\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}}};
# /* ]]> */
# </script>
# <script src="https://media.boingboing.net/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.0.4" type="text/javascript"></script>
# <script src="https://s0.wp.com/wp-content/js/devicepx-jetpack.js?ver=201836" type="text/javascript"></script>
# <script async="async" defer="defer" src="https://stats.wp.com/e-201836.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:6.5',blog:'87954168',post:'421667',tz:'-7',srv:'boingboing.net'} ]);
# 	_stq.push([ 'clickTrackerInit', '87954168', '421667' ]);
# </script>
# <script>jQuery(function(){jQuery('#sidebar').height(jQuery('#features').height())});</script>
# <!-- Analytics-->
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-QX6JKE-6M4Jf7"
# });
# </script>
# <noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-QX6JKE-6M4Jf7.gif" width="1"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# <!-- Google Analytics include -->
# <script>
# function clickTrack(url, action, label){
#     if(url && action && label){
#         clickedURL = url;
#         if(typeof(event) != "undefined") event.returnValue = false;
#         ga('send', 'event', {
#             'eventCategory' : 'UI Click',
#             'eventAction'   : action,
#             'eventLabel'    : label,
#             'hitCallback'   : function () {
#                 document.location = clickedURL;
#             }
#         });
#         return false;
#     }
#     return true;
# }
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-3839311-1', 'auto');
#
#
#   ga('send', 'pageview');
#
# </script>
# <!-- end Google Analytics include -->
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "7518287" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript><img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=7518287&amp;cv=2.0&amp;cj=1"/></noscript>
# <!-- End comScore Tag -->
# <script>
# 		function showmenu() {
# 			var currentHeight = document.getElementById("menuitems").style.height;
# 			if (currentHeight == "250px") {
# 				document.getElementById("menuitems").style.height = "0px";
# 			} else {
# 				document.getElementById("menuitems").style.height = "250px";
# 			}
# 		}
# </script>
# <script src="https://tags.crwdcntrl.net/c/8753/cc_af.js"></script>
# <script>
#     function createCookie(name,value,days) {
#     var expires;
#     if (days) {
#         var date = new Date();
#         date.setTime(date.getTime()+(days*24*60*60*1000));
#         expires = "; expires="+date.toGMTString();
#     }
#     else {
#         expires = "";
#     }
#     document.cookie = name+"="+value+expires+"; path=/";
# }
#
# function readCookie(name) {
#     var nameEQ = name + "=";
#     var ca = document.cookie.split(';');
#     for(var i=0;i < ca.length;i++) {
#         var c = ca[i];
#         while (c.charAt(0)==' ') c = c.substring(1,c.length);
#         if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
#     }
#     return null;
# }
#
# var BNGEnqueueMC = readCookie('BNGEnqueueMC');
#
# if( 'yes' === BNGEnqueueMC ) {
#     // Embed scripts
#     var mc1 = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#     mc1.src = '//downloads.mailchimp.com/js/signup-forms/popup/embed.js';
#     mc1.setAttribute('data-dojo-config', 'usePlainJson: true, isDebug: false');
#     el.parentNode.insertBefore(mc1, el);
#     var mcInterval = setInterval(function(){
#         if( 'function' === typeof PopupSignupForm) {
#           require(["mojo/signup-forms/Loader"], function(L) { L.start({"baseUrl":"mc.us2.list-manage.com","uuid":"0e91f8e7df61da4bff2bd9b1f","lid":"8c5d27370d"}) });
#           clearInterval(mcInterval);
#         }
#     }, 250);
# } else {
#     createCookie('BNGEnqueueMC', 'yes', 30);
# }
# </script>
# </body></html>

# %%
# Lets scan for a particular thing. Lets scan for all links in the webpage.
# Links are coded as anchor tag(<a href="link">). Hence lets find all the anchor tag and get the link which it is pointing too. 
for link in soup.find_all('a'): # scarping the links by extracting the text in href of <a> tag(HTML) 
    print(link.get('href'))
# Out:
# https://boingboing.net
# http://boingboing.net/sub
# https://boingboing.net/search
# https://store.boingboing.net
# javascript:void(0)
# http://boingboing.net/blog
# http://bbs.boingboing.net
# https://bbs.boingboing.net/faq
# http://store.boingboing.net
# mailto:pubsupport@stackcommerce.com
# http://boingboing.net/about
# http://boingboing.net/contact
# http://boingboing.net/advertise
# http://boingboing.net/privacy
# http://boingboing.net/tos
# https://boingboing.net/2018/09/08/trump-planned-venezuela-coup.html
# https://boingboing.net/tag/war
# https://boingboing.net/2018/09/08/trump-planned-venezuela-coup.html
# https://boingboing.net/author/rob_beschizza
# https://boingboing.net/2018/09/08/fitness-youtuber-breaks-down-j.html
# https://boingboing.net/tag/recording-industry
# https://boingboing.net/2018/09/08/fitness-youtuber-breaks-down-j.html
# https://boingboing.net/author/andrea_james_1
# https://boingboing.net/2018/09/08/a-candle-that-smells-like-chin.html
# https://boingboing.net/tag/Chinese-food
# https://boingboing.net/2018/09/08/a-candle-that-smells-like-chin.html
# https://boingboing.net/author/blazenhoff_1
# #
# http://twitter.com/boingboing
# https://www.facebook.com/boingboing
# http://boingboing.net/feed
# https://boingboing.net/2018/09/08/george-zimmerman-threatened-to.html
# https://boingboing.net/tag/trayvon
# https://boingboing.net/2018/09/08/george-zimmerman-threatened-to.html
# https://boingboing.net/author/rob_beschizza
# https://store.boingboing.net
# https://boingboing.net/2018/09/08/why-you-should-build-your-bran.html
# https://boingboing.net/2018/09/08/why-you-should-build-your-bran.html
# https://boingboing.net/2018/09/08/homeless-students.html
# https://boingboing.net/tag/asset-bubbles
# https://boingboing.net/2018/09/08/homeless-students.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/08/the-mystery-of-tucker-carl.html
# https://boingboing.net/tag/twerps
# https://boingboing.net/2018/09/08/the-mystery-of-tucker-carl.html
# https://boingboing.net/author/rob_beschizza
# https://boingboing.net/2018/09/08/instant-noodle-action-figures.html
# https://boingboing.net/tag/noodles
# https://boingboing.net/2018/09/08/instant-noodle-action-figures.html
# https://boingboing.net/author/andrea_james_1
# https://boingboing.net/2018/09/08/britains-channel-4-highlight.html
# https://boingboing.net/tag/media
# https://boingboing.net/2018/09/08/britains-channel-4-highlight.html
# https://boingboing.net/author/rob_beschizza
# https://boingboing.net/2018/09/08/gentleman-extracts-sixth-toile.html
# https://boingboing.net/tag/non-delightful-creatures
# https://boingboing.net/2018/09/08/gentleman-extracts-sixth-toile.html
# https://boingboing.net/author/andrea_james_1
# https://boingboing.net/2018/09/08/infamous-inverted-jenny-st.html
# https://boingboing.net/tag/stamp
# https://boingboing.net/2018/09/08/infamous-inverted-jenny-st.html
# https://boingboing.net/author/andrea_james_1
# https://boingboing.net/2018/09/08/the-playlist-of-the-2018-burni.html
# https://boingboing.net/tag/DJ-set
# https://boingboing.net/2018/09/08/the-playlist-of-the-2018-burni.html
# https://boingboing.net/author/blazenhoff_1
# https://boingboing.net/2018/09/07/x-atencio-r-us.html
# https://boingboing.net/tag/grim-grinning-ghosts
# https://boingboing.net/2018/09/07/x-atencio-r-us.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/george-papadopoulos-gets-14-da.html
# https://boingboing.net/tag/coffee-boy
# https://boingboing.net/2018/09/07/george-papadopoulos-gets-14-da.html
# https://boingboing.net/author/ginaloukareas
# https://boingboing.net/2018/09/07/bug-eyed-monsters.html
# https://boingboing.net/tag/inside-jobs
# https://boingboing.net/2018/09/07/bug-eyed-monsters.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/pla-vs-appl.html
# https://boingboing.net/tag/adware-doctor
# https://boingboing.net/2018/09/07/pla-vs-appl.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/america-doxed.html
# https://boingboing.net/tag/congress-inaction
# https://boingboing.net/2018/09/07/america-doxed.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/developers-developers-develope-2.html
# https://boingboing.net/tag/if-there-is-hope-it-is-in-the-proles
# https://boingboing.net/2018/09/07/developers-developers-develope-2.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/i-just-burnt-an-hour-looking-f.html
# https://boingboing.net/tag/Ever-changing-Apple-cable-formats
# https://boingboing.net/2018/09/07/i-just-burnt-an-hour-looking-f.html
# https://boingboing.net/author/jason
# https://boingboing.net/2018/09/07/los-chicago-boys.html
# https://boingboing.net/tag/i-hate-you-ronald-reagan
# https://boingboing.net/2018/09/07/los-chicago-boys.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/lipstick-for-ugly-ugly-pigs.html
# https://boingboing.net/tag/axl-voss
# https://boingboing.net/2018/09/07/lipstick-for-ugly-ugly-pigs.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/it-pays-to-haggle-over-your-ca.html
# https://boingboing.net/tag/saving-money
# https://boingboing.net/2018/09/07/it-pays-to-haggle-over-your-ca.html
# https://boingboing.net/author/mark_frauenfelder_1
# https://boingboing.net/2018/09/07/free-wechat.html
# https://boingboing.net/tag/ocr
# https://boingboing.net/2018/09/07/free-wechat.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/destiny-2-foresaken-may-be-to.html
# https://boingboing.net/tag/byf
# https://boingboing.net/2018/09/07/destiny-2-foresaken-may-be-to.html
# https://boingboing.net/author/jason
# https://boingboing.net/2018/09/07/trump-justice-dept-should-inv.html
# https://boingboing.net/tag/freedom-of-the-press
# https://boingboing.net/2018/09/07/trump-justice-dept-should-inv.html
# https://boingboing.net/author/xeni_jardin
# https://boingboing.net/2018/09/07/video-a-fun-burning-man-2018.html
# https://boingboing.net/tag/hyperlapse
# https://boingboing.net/2018/09/07/video-a-fun-burning-man-2018.html
# https://boingboing.net/author/xeni_jardin
# https://boingboing.net/2018/09/07/sharing-is-caring-2.html
# https://boingboing.net/tag/#saveyourinternet
# https://boingboing.net/2018/09/07/sharing-is-caring-2.html
# https://boingboing.net/author/cory_doctorow_1
# https://boingboing.net/2018/09/07/nazi-puncher-fined-1.html
# https://boingboing.net/tag/extremism
# https://boingboing.net/2018/09/07/nazi-puncher-fined-1.html
# https://boingboing.net/author/andrea_james_1
# https://boingboing.net/2018/09/07/academic-freedom-grifters-rall.html
# https://boingboing.net/tag/Retraction-Watch
# https://boingboing.net/2018/09/07/academic-freedom-grifters-rall.html
# https://boingboing.net/author/andrea_james_1
# https://boingboing.net/grid/page/2/
# http://boingboing.net/tos
# http://boingboing.net/privacy
# http://bbs.boingboing.net/faq
# http://creativecommons.org/licenses/by-nc-sa/3.0/deed.en_US
# http://twitter.com/frauenfelder
# http://twitter.com/doctorow
# http://twitter.com/pesco
# http://twitter.com/xeni
# http://twitter.com/beschizza
# http://twitter.com/jlw
# http://twitter.com/orenwolf
# https://boingboing.net/about
# https://boingboing.net/contact
# https://boingboing.net/advertise
# http://bbs.boingboing.net
# http://store.boingboing.net
# mailto:pubsupport@stackcommerce.com

# %% [markdown]
# <span style='color:green'>Tadaa, we were able to compete our objective and extract the links. There might be chances of few non-links also to appear.</span>
#
# <span style='color:red'>Note: Web technology is evolving day by day and lot of frameworks are advancing. Most of them render content dynamically and hence the content cannot be caught in response text</span>

# %% [markdown]
# <br><br>
# <center><h2>End of Book</h2></center>

# %% [markdown]
# <hr>
# <h3><b>Next book :</b> Book 0.1. Zen of Python</h3>
#
# https://github.com/atcodedog
#
# <b><a href='index.html'>Back Home</a></b>
# <hr>

# %% [markdown]
# Source from atcodedog git repo
#
# Find more on
#
# https://github.com/atcodedog
#
# http://www.atcodedog.com
#
# Follow us on
#
# https://twitter.com/atcodedog
